# %% [markdown]
# # Lab | Pandas

# %% [markdown]
# In this lab, we will be working with the customer data from an insurance company, which can be found in the CSV file located at the following link: https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# The data includes information such as customer ID, state, gender, education, income, and other variables that can be used to perform various analyses.
#
# Throughout the lab, we will be using the pandas library in Python to manipulate and analyze the data. Pandas is a powerful library that provides various data manipulation and analysis tools, including the ability to load and manipulate data from a variety of sources, including CSV files.

# %% [markdown]
# ### Data Description
#
# - Customer - Customer ID
#
# - ST - State where customers live
#
# - Gender - Gender of the customer
#
# - Education - Background education of customers
#
# - Customer Lifetime Value - Customer lifetime value(CLV) is the total revenue the client will derive from their entire relationship with a customer. In other words, is the predicted or calculated value of a customer over their entire duration as a policyholder with the insurance company. It is an estimation of the net profit that the insurance company expects to generate from a customer throughout their relationship with the company. Customer Lifetime Value takes into account factors such as the duration of the customer's policy, premium payments, claim history, renewal likelihood, and potential additional services or products the customer may purchase. It helps insurers assess the long-term profitability and value associated with retaining a particular customer.
#
# - Income - Customers income
#
# - Monthly Premium Auto - Amount of money the customer pays on a monthly basis as a premium for their auto insurance coverage. It represents the recurring cost that the insured person must pay to maintain their insurance policy and receive coverage for potential damages, accidents, or other covered events related to their vehicle.
#
# - Number of Open Complaints - Number of complaints the customer opened
#
# - Policy Type - There are three type of policies in car insurance (Corporate Auto, Personal Auto, and Special Auto)
#
# - Vehicle Class - Type of vehicle classes that customers have Two-Door Car, Four-Door Car SUV, Luxury SUV, Sports Car, and Luxury Car
#
# - Total Claim Amount - the sum of all claims made by the customer. It represents the total monetary value of all approved claims for incidents such as accidents, theft, vandalism, or other covered events.

# %% [markdown]
# External Resources: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %% [markdown]
# ## Challenge 1: Understanding the data
#
# In this challenge, you will use pandas to explore a given dataset. Your task is to gain a deep understanding of the data by analyzing its characteristics, dimensions, and statistical properties.

# %% [markdown]
# - Identify the dimensions of the dataset by determining the number of rows and columns it contains.
# - Determine the data types of each column and evaluate whether they are appropriate for the nature of the variable. You should also provide suggestions for fixing any incorrect data types.
# - Identify the number of unique values for each column and determine which columns appear to be categorical. You should also describe the unique values of each categorical column and the range of values for numerical columns, and give your insights.
# - Compute summary statistics such as mean, median, mode, standard deviation, and quartiles to understand the central tendency and distribution of the data for numerical columns. You should also provide your conclusions based on these summary statistics.
# - Compute summary statistics for categorical columns and providing your conclusions based on these statistics.

# %%
import pandas as pd#categorical values

# %%
ds = pd.read_csv("Livro1.csv")
ds
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#      Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                        NaN       0                  1000
# 1                 697953.59%       0                    94
# 2                1288743.17%   48767                   108
# 3                 764586.18%       0                   106
# ...

# %%
ds.shape #dentify the dimensions of the dataset by determining the number of rows and columns it contains.
# Out:
# (1071, 11)

# %%
ds.dtypes #Determine the data types of each column 
#evaluate whether they are appropriate for the nature of the variable: Customer Lifetime Value; Number of Open Complaints
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                         int64
# Monthly Premium Auto           int64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
ds[ds["Customer Lifetime Value"].isnull()] # ver quais os Nan
# Out:
#     Customer          ST GENDER             Education Customer Lifetime Value  \
# 0    RB50392  Washington    NaN                Master                     NaN
# 78   SP81997  Washington      F                Master                     NaN
# 988  GT62080  Washington      M  High School or Below                     NaN
#
#      Income  Monthly Premium Auto Number of Open Complaints    Policy Type  \
# 0         0                  1000                    1/0/00  Personal Auto
# 78    41275                    96                    1/0/00  Personal Auto
# 988   55561                    63                    1/0/00  Personal Auto
#
#      Vehicle Class  Total Claim Amount
# 0    Four-Door Car            2.704934
# 78   Four-Door Car           41.122303
# 988  Four-Door Car          227.872071

# %%
ds = ds.fillna(0) #passar os Nan para 0 
ds
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington      0                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#      Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                          0       0                  1000
# 1                 697953.59%       0                    94
# 2                1288743.17%   48767                   108
# 3                 764586.18%       0                   106
# ...

# %%
ds["Customer Lifetime Value"] = ds["Customer Lifetime Value"].str.rstrip('%').apply(pd.to_numeric, errors='coerce') # tirar as %

# %%
ds # confirmar que está sem %
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington      0                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                         NaN       0                  1000
# 1                   697953.59       0                    94
# 2                  1288743.17   48767                   108
# ...

# %%
ds = ds.fillna(0) #passar os Nan para 0 
ds["Customer Lifetime Value"] = ds["Customer Lifetime Value"].astype(int)

# %%
ds #change Customer Lifetime Value para integer
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington      0                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                           0       0                  1000
# 1                      697953       0                    94
# 2                     1288743   48767                   108
# ...

# %%
ds["Number of Open Complaints"].unique() #unique values
# Out:
# array(['1/0/00', '01/02/2000', '01/01/2000', '01/03/2000', '01/05/2000',
#        '01/04/2000'], dtype=object)

# %%
ds["Number of Open Complaints"] = ds["Number of Open Complaints"].str.rstrip('/').apply(pd.to_numeric, errors='coerce') # tirar a /

# %%
ds = ds.fillna(0) #passar os Nan para 0 
ds
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington      0                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                           0       0                  1000
# 1                      697953       0                    94
# 2                     1288743   48767                   108
# ...

# %%
display(ds["Customer"].nunique())
display(ds["ST"].nunique())  #categorical values
display(ds["GENDER"].nunique()) #categorical values
display(ds["Education"].nunique()) #categorical values
display(ds["Customer Lifetime Value"].nunique())
display(ds["Income"].nunique())
display(ds["Monthly Premium Auto"].nunique())
display(ds["Number of Open Complaints"].nunique()) #categorical values
display(ds["Policy Type"].nunique()) #categorical values
display(ds["Vehicle Class"].nunique()) #categorical values
display(ds["Total Claim Amount"].nunique())
# Out:
# 1071
# 8
# 6
# 6
# 1028
# 774
# 132
# 1
# 3
# 6
# 761

# %%
#describe the unique values of each categorical column and the range of values for numerical columns, and give your insights.
display(ds["ST"].unique())  #categorical values
display(ds["GENDER"].unique()) #categorical values - F, Femal, and Female should all be one value as Male and M'
display(ds["Education"].unique()) #categorical values - Bachelor' and Bachelors' should also be one unique value
display(ds["Number of Open Complaints"].unique()) #categorical values
display(ds["Policy Type"].unique()) #categorical values
display(ds["Vehicle Class"].unique()) #categorical values
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA'], dtype=object)
# array([0, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)
# array(['Master', 'Bachelor', 'High School or Below', 'College',
#        'Bachelors', 'Doctor'], dtype=object)
# array([0.])
# array(['Personal Auto', 'Corporate Auto', 'Special Auto'], dtype=object)
# array(['Four-Door Car', 'Two-Door Car', 'SUV', 'Luxury SUV', 'Sports Car',
#        'Luxury Car'], dtype=object)

# %%
#Compute summary statistics such as mean, median, mode, standard deviation, and quartiles to understand the central tendency and distribution of the data for numerical columns. 

ds.describe()

#You should also provide your conclusions based on these summary statistics.

#customer lifetime value: it has very big numbers 
#income has a average of 39295,70 and the minimum is 0
#monthly premium auto: it has 1071 customers using the monthly premium
#number of open complaints: it always have 0, because I could not change the type, so I assume that it was 0, because it appear Nan
#total claim amount: it has a average of 404,98.
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count             1.071000e+03   1071.000000           1071.000000
# mean              7.914665e+05  39295.701214            193.234360
# std               6.439447e+05  30469.427060           1601.190369
# min               0.000000e+00      0.000000             61.000000
# 25%               4.019750e+05  14072.000000             68.000000
# 50%               5.849320e+05  36234.000000             83.000000
# 75%               8.945205e+05  64631.000000            109.500000
# max               5.816655e+06  99960.000000          35354.000000
#
#        Number of Open Complaints  Total Claim Amount
# count                     1071.0         1071.000000
# mean                         0.0          404.986909
# std                          0.0          293.027260
# min                          0.0            0.382107
# 25%                          0.0          202.157702
# ...

# %%
ds
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington      0                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                           0       0                  1000
# 1                      697953       0                    94
# 2                     1288743   48767                   108
# ...

# %%
display(ds["ST"].describe()) #Compute summary statistics for categorical columns and providing your conclusions based on these statistics.
display(ds["GENDER"].describe())
display(ds["Education"].describe())
display(ds["Number of Open Complaints"].describe())
display(ds["Policy Type"].describe())
display(ds["Vehicle Class"].describe())
# Out:
# count       1071
# unique         8
# top       Oregon
# freq         320
# Name: ST, dtype: object
# count     1071
# unique       6
# top          F
# freq       457
# Name: GENDER, dtype: object
# count         1071
# unique           6
# top       Bachelor
# freq           324
# Name: Education, dtype: object
# count    1071.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: Number of Open Complaints, dtype: float64
# count              1071
# unique                3
# top       Personal Auto
# freq                780
# Name: Policy Type, dtype: object
# count              1071
# unique                6
# top       Four-Door Car
# freq                576
# Name: Vehicle Class, dtype: object

# %% [markdown]
# ## Challenge 2: analyzing the data

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# The marketing team wants to know the top 5 less common customer locations. Create a pandas Series object that contains the customer locations and their frequencies, and then retrieve the top 5 less common locations in ascending order.

# %%
# Your code here
import pandas as pd

# %%
ds = pd.read_csv("Livro1.csv")
ds
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#      Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                        NaN       0                  1000
# 1                 697953.59%       0                    94
# 2                1288743.17%   48767                   108
# 3                 764586.18%       0                   106
# ...

# %%
location_counts = ds["ST"].value_counts()
location_series = pd.Series(location_counts,name ="location")
location_series
#Create a pandas Series object that contains the customer locations and their frequencies
# Out:
# ST
# Oregon        320
# California    211
# Arizona       186
# Cali          120
# Nevada         98
# Washington     81
# WA             30
# AZ             25
# Name: location, dtype: int64

# %%
# and then retrieve the top 5 less common locations in ascending order.
sorted_location = location_series.sort_values(ascending = True)
top_less_common = sorted_location.head(5)
top_less_common
# Out:
# ST
# AZ             25
# WA             30
# Washington     81
# Nevada         98
# Cali          120
# Name: location, dtype: int64

# %% [markdown]
# ### Exercise 2
#
# The sales team wants to know the total number of policies sold for each type of policy. Create a pandas Series object that contains the policy types and their total number of policies sold, and then retrieve the policy type with the highest number of policies sold.

# %% [markdown]
# *Hint:*
# - *Using value_counts() method simplifies this analysis.*
# - *Futhermore, there is a method that returns the index of the maximum value in a column or row.*

# %%
policy_counts = ds["Policy Type"].value_counts()
policy_series = pd.Series(policy_counts,name ="Policy Type")
policy_series
#Create a pandas Series object that contains the policy types and their total number of policies sold
# Out:
# Policy Type
# Personal Auto     780
# Corporate Auto    234
# Special Auto       57
# Name: Policy Type, dtype: int64

# %%
policy_series.idxmax() #and then retrieve the policy type with the highest number of policies sold.
# Out:
# 'Personal Auto'

# %% [markdown]
# ### Exercise 3
#
# The sales team wants to know if customers with Personal Auto have a lower income than those with Corporate Auto. How does the average income compare between the two policy types?

# %% [markdown]
# - Use *loc* to create two dataframes: one containing only Personal Auto policies and one containing only Corporate Auto policies.
# - Calculate the average income for each policy.
# - Print the results.

# %%
personal_auto = ds.loc[ds['Policy Type'] == 'Personal Auto']
auto_policy = personal_auto.loc[0:1071,"Income":"Policy Type"]
auto_policy
# Out:
#       Income  Monthly Premium Auto Number of Open Complaints    Policy Type
# 0          0                  1000                    1/0/00  Personal Auto
# 1          0                    94                    1/0/00  Personal Auto
# 2      48767                   108                    1/0/00  Personal Auto
# 4      36357                    68                    1/0/00  Personal Auto
# 5      62902                    69                    1/0/00  Personal Auto
# 10         0                    67                    1/0/00  Personal Auto
# 11         0                   110                    1/0/00  Personal Auto
# 16     25049                    67                    1/0/00  Personal Auto
# 17     28855                   101                    1/0/00  Personal Auto
# 18     51148                    72                    1/0/00  Personal Auto
# 20     57749                    74                    1/0/00  Personal Auto
# ...

# %%
mean_auto = auto_policy.groupby("Policy Type")["Income"].mean()
mean_auto
# Out:
# Policy Type
# Personal Auto    38180.698718
# Name: Income, dtype: float64

# %%
corporate_auto  = ds.loc[ds['Policy Type'] == 'Corporate Auto']
corporate_policy = corporate_auto.loc[0:1071,"Income":"Policy Type"]
corporate_policy
# Out:
#       Income  Monthly Premium Auto Number of Open Complaints     Policy Type
# 3          0                   106                    1/0/00  Corporate Auto
# 6      55350                    67                    1/0/00  Corporate Auto
# 7          0                   101                    1/0/00  Corporate Auto
# 8      14072                    71                    1/0/00  Corporate Auto
# 12     77026                   110                01/02/2000  Corporate Auto
# 13     99845                   110                01/01/2000  Corporate Auto
# 14     83689                    70                01/02/2000  Corporate Auto
# 15     24599                    64                01/01/2000  Corporate Auto
# 19     66140                   101                    1/0/00  Corporate Auto
# 23         0                    73                01/03/2000  Corporate Auto
# 24     17870                    61                    1/0/00  Corporate Auto
# ...

# %%
mean_corporate = corporate_policy.groupby("Policy Type")["Income"].mean()
mean_corporate
# Out:
# Policy Type
# Corporate Auto    41390.311966
# Name: Income, dtype: float64

# %% [markdown]
# ### Bonus: Exercise 4

# %% [markdown]
# Your goal is to identify customers with a high policy claim amount.
#
# Instructions:
#
# - Review again the statistics for total claim amount to gain an understanding of the data.
# - To identify potential areas for improving customer retention and profitability, we want to focus on customers with a high policy claim amount. Consider customers with a high policy claim amount to be those in the top 25% of the total claim amount. Create a pandas DataFrame object that contains information about customers with a policy claim amount greater than the 75th percentile.
# - Use DataFrame methods to calculate summary statistics about the high policy claim amount data.

# %% [markdown]
# *Note: When analyzing data, we often want to focus on certain groups of values to gain insights. Percentiles are a useful tool to help us define these groups. A percentile is a measure that tells us what percentage of values in a dataset are below a certain value. For example, the 75th percentile represents the value below which 75% of the data falls. Similarly, the 25th percentile represents the value below which 25% of the data falls. When we talk about the top 25%, we are referring to the values that fall above the 75th percentile, which represent the top quarter of the data. On the other hand, when we talk about the bottom 25%, we are referring to the values that fall below the 25th percentile, which represent the bottom quarter of the data. By focusing on these groups, we can identify patterns and trends that may be useful for making decisions and taking action.*
#
# *Hint: look for a method that gives you the percentile or quantile 0.75 and 0.25 for a Pandas Series.*

# %% [markdown]
# *Hint 2: check `Boolean selection according to the values of a single column` in https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9*

# %%
# Your code here
